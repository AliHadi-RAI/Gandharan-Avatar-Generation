# %% [markdown]
# # **1. Installing Libraries**

# %%
# Installs crewaI and crewaI-tools Python packages for agent-based workflows and tool integrations.
# !pip install crewai crewai-tools
# Out:
# Collecting crewai
#   Downloading crewai-0.121.0-py3-none-any.whl.metadata (33 kB)
# Collecting crewai-tools
#   Downloading crewai_tools-0.45.0-py3-none-any.whl.metadata (10 kB)
# Collecting appdirs>=1.4.4 (from crewai)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting auth0-python>=4.7.1 (from crewai)
#   Downloading auth0_python-4.9.0-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from crewai) (1.9.0)
# Collecting chromadb>=0.5.23 (from crewai)
#   Downloading chromadb-1.0.10-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.9 kB)
# Requirement already satisfied: click>=8.1.7 in /usr/local/lib/python3.11/dist-packages (from crewai) (8.2.0)
# Collecting instructor>=1.3.3 (from crewai)
#   Downloading instructor-1.8.3-py3-none-any.whl.metadata (24 kB)
# Collecting json-repair>=0.25.2 (from crewai)
#   Downloading json_repair-0.46.0-py3-none-any.whl.metadata (12 kB)
# Collecting json5>=0.10.0 (from crewai)
#   Downloading json5-0.12.0-py3-none-any.whl.metadata (36 kB)
# Collecting jsonref>=1.1.0 (from crewai)
#   Downloading jsonref-1.1.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting litellm==1.68.0 (from crewai)
#   Downloading litellm-1.68.0-py3-none-any.whl.metadata (36 kB)
# Requirement already satisfied: openai>=1.13.3 in /usr/local/lib/python3.11/dist-packages (from crewai) (1.78.1)
# Requirement already satisfied: openpyxl>=3.1.5 in /usr/local/lib/python3.11/dist-packages (from crewai) (3.1.5)
# Collecting opentelemetry-api>=1.30.0 (from crewai)
#   Downloading opentelemetry_api-1.33.1-py3-none-any.whl.metadata (1.6 kB)
# Collecting opentelemetry-exporter-otlp-proto-http>=1.30.0 (from crewai)
#   Downloading opentelemetry_exporter_otlp_proto_http-1.33.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-sdk>=1.30.0 (from crewai)
#   Downloading opentelemetry_sdk-1.33.1-py3-none-any.whl.metadata (1.6 kB)
# Collecting pdfplumber>=0.11.4 (from crewai)
#   Downloading pdfplumber-0.11.6-py3-none-any.whl.metadata (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: pydantic>=2.4.2 in /usr/local/lib/python3.11/dist-packages (from crewai) (2.11.4)
# Collecting python-dotenv>=1.0.0 (from crewai)
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Collecting pyvis>=0.3.2 (from crewai)
#   Downloading pyvis-0.3.2-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: regex>=2024.9.11 in /usr/local/lib/python3.11/dist-packages (from crewai) (2024.11.6)
# Collecting tomli-w>=1.1.0 (from crewai)
#   Downloading tomli_w-1.2.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting tomli>=2.0.2 (from crewai)
#   Downloading tomli-2.2.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting uv>=0.4.25 (from crewai)
#   Downloading uv-0.7.8-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from litellm==1.68.0->crewai) (3.11.15)
# Requirement already satisfied: httpx>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from litellm==1.68.0->crewai) (0.28.1)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /usr/local/lib/python3.11/dist-packages (from litellm==1.68.0->crewai) (8.7.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in /usr/local/lib/python3.11/dist-packages (from litellm==1.68.0->crewai) (3.1.6)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from litellm==1.68.0->crewai) (4.23.0)
# Collecting openai>=1.13.3 (from crewai)
#   Downloading openai-1.75.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: tiktoken>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from litellm==1.68.0->crewai) (0.9.0)
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.11/dist-packages (from litellm==1.68.0->crewai) (0.21.1)
# Collecting docker>=7.1.0 (from crewai-tools)
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting embedchain>=0.1.114 (from crewai-tools)
#   Downloading embedchain-0.1.128-py3-none-any.whl.metadata (9.2 kB)
# Collecting lancedb>=0.5.4 (from crewai-tools)
#   Downloading lancedb-0.22.1-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (4.4 kB)
# Collecting pyright>=1.1.350 (from crewai-tools)
#   Downloading pyright-1.1.401-py3-none-any.whl.metadata (6.6 kB)
# Collecting pytube>=15.0.0 (from crewai-tools)
#   Downloading pytube-15.0.0-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.11/dist-packages (from crewai-tools) (2.32.3)
# Requirement already satisfied: cryptography>=43.0.1 in /usr/local/lib/python3.11/dist-packages (from auth0-python>=4.7.1->crewai) (43.0.3)
# Requirement already satisfied: pyjwt>=2.8.0 in /usr/local/lib/python3.11/dist-packages (from auth0-python>=4.7.1->crewai) (2.10.1)
# Requirement already satisfied: urllib3>=2.2.3 in /usr/local/lib/python3.11/dist-packages (from auth0-python>=4.7.1->crewai) (2.4.0)
# Requirement already satisfied: build>=1.0.3 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (1.2.2.post1)
# Collecting fastapi==0.115.9 (from chromadb>=0.5.23->crewai)
#   Downloading fastapi-0.115.9-py3-none-any.whl.metadata (27 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai)
#   Downloading uvicorn-0.34.2-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy>=1.22.5 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (2.0.2)
# Collecting posthog>=2.4.0 (from chromadb>=0.5.23->crewai)
#   Downloading posthog-4.2.0-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (4.13.2)
# Collecting onnxruntime>=1.14.1 (from chromadb>=0.5.23->crewai)
#   Downloading onnxruntime-1.22.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb>=0.5.23->crewai)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.33.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb>=0.5.23->crewai)
#   Downloading opentelemetry_instrumentation_fastapi-0.54b1-py3-none-any.whl.metadata (2.2 kB)
# Collecting pypika>=0.48.9 (from chromadb>=0.5.23->crewai)
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 3.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (4.67.1)
# Collecting overrides>=7.3.1 (from chromadb>=0.5.23->crewai)
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (1.71.0)
# Collecting bcrypt>=4.0.1 (from chromadb>=0.5.23->crewai)
#   Downloading bcrypt-4.3.0-cp39-abi3-manylinux_2_34_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (0.15.3)
# Collecting kubernetes>=28.1.0 (from chromadb>=0.5.23->crewai)
#   Downloading kubernetes-32.0.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (9.1.2)
# Requirement already satisfied: pyyaml>=6.0.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (6.0.2)
# Collecting mmh3>=4.0.1 (from chromadb>=0.5.23->crewai)
#   Downloading mmh3-5.1.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (16 kB)
# Requirement already satisfied: orjson>=3.9.12 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (3.10.18)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (13.9.4)
# Collecting starlette<0.46.0,>=0.40.0 (from fastapi==0.115.9->chromadb>=0.5.23->crewai)
#   Downloading starlette-0.45.3-py3-none-any.whl.metadata (6.3 kB)
# Collecting alembic<2.0.0,>=1.13.1 (from embedchain>=0.1.114->crewai-tools)
#   Downloading alembic-1.16.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from embedchain>=0.1.114->crewai-tools) (4.13.4)
# Collecting chromadb>=0.5.23 (from crewai)
#   Downloading chromadb-0.5.23-py3-none-any.whl.metadata (6.8 kB)
# Collecting gptcache<0.2.0,>=0.1.43 (from embedchain>=0.1.114->crewai-tools)
#   Downloading gptcache-0.1.44-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: langchain<0.4.0,>=0.3.1 in /usr/local/lib/python3.11/dist-packages (from embedchain>=0.1.114->crewai-tools) (0.3.25)
# Collecting langchain-cohere<0.4.0,>=0.3.0 (from embedchain>=0.1.114->crewai-tools)
#   Downloading langchain_cohere-0.3.5-py3-none-any.whl.metadata (6.7 kB)
# Collecting langchain-community<0.4.0,>=0.3.1 (from embedchain>=0.1.114->crewai-tools)
#   Downloading langchain_community-0.3.24-py3-none-any.whl.metadata (2.5 kB)
# Collecting langchain-openai<0.3.0,>=0.2.1 (from embedchain>=0.1.114->crewai-tools)
#   Downloading langchain_openai-0.2.14-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: langsmith<0.4.0,>=0.3.18 in /usr/local/lib/python3.11/dist-packages (from embedchain>=0.1.114->crewai-tools) (0.3.42)
# Collecting mem0ai<0.2.0,>=0.1.54 (from embedchain>=0.1.114->crewai-tools)
#   Downloading mem0ai-0.1.101-py3-none-any.whl.metadata (7.4 kB)
# Collecting posthog>=2.4.0 (from chromadb>=0.5.23->crewai)
#   Downloading posthog-3.25.0-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting pypdf<6.0.0,>=5.0.0 (from embedchain>=0.1.114->crewai-tools)
#   Downloading pypdf-5.5.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting pysbd<0.4.0,>=0.3.4 (from embedchain>=0.1.114->crewai-tools)
#   Downloading pysbd-0.3.4-py3-none-any.whl.metadata (6.1 kB)
# Collecting schema<0.8.0,>=0.7.5 (from embedchain>=0.1.114->crewai-tools)
#   Downloading schema-0.7.7-py2.py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: sqlalchemy<3.0.0,>=2.0.27 in /usr/local/lib/python3.11/dist-packages (from embedchain>=0.1.114->crewai-tools) (2.0.40)
# Collecting chroma-hnswlib==0.7.6 (from chromadb>=0.5.23->crewai)
#   Downloading chroma_hnswlib-0.7.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (252 bytes)
# Collecting fastapi>=0.95.2 (from chromadb>=0.5.23->crewai)
#   Downloading fastapi-0.115.12-py3-none-any.whl.metadata (27 kB)
# Collecting tokenizers (from litellm==1.68.0->crewai)
#   Downloading tokenizers-0.20.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: docstring-parser<1.0,>=0.16 in /usr/local/lib/python3.11/dist-packages (from instructor>=1.3.3->crewai) (0.16)
# Collecting jiter<0.9,>=0.6.1 (from instructor>=1.3.3->crewai)
#   Downloading jiter-0.8.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.0 in /usr/local/lib/python3.11/dist-packages (from instructor>=1.3.3->crewai) (2.33.2)
# Collecting deprecation (from lancedb>=0.5.4->crewai-tools)
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from lancedb>=0.5.4->crewai-tools) (24.2)
# Requirement already satisfied: pyarrow>=16 in /usr/local/lib/python3.11/dist-packages (from lancedb>=0.5.4->crewai-tools) (18.1.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.13.3->crewai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.13.3->crewai) (1.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai>=1.13.3->crewai) (1.3.1)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.11/dist-packages (from openpyxl>=3.1.5->crewai) (2.0.0)
# Collecting deprecated>=1.2.6 (from opentelemetry-api>=1.30.0->crewai)
#   Downloading Deprecated-1.2.18-py2.py3-none-any.whl.metadata (5.7 kB)
# Collecting importlib-metadata>=6.8.0 (from litellm==1.68.0->crewai)
#   Downloading importlib_metadata-8.6.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-otlp-proto-http>=1.30.0->crewai) (1.70.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.33.1 (from opentelemetry-exporter-otlp-proto-http>=1.30.0->crewai)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.33.1-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-proto==1.33.1 (from opentelemetry-exporter-otlp-proto-http>=1.30.0->crewai)
#   Downloading opentelemetry_proto-1.33.1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: protobuf<6.0,>=5.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-proto==1.33.1->opentelemetry-exporter-otlp-proto-http>=1.30.0->crewai) (5.29.4)
# Collecting opentelemetry-semantic-conventions==0.54b1 (from opentelemetry-sdk>=1.30.0->crewai)
#   Downloading opentelemetry_semantic_conventions-0.54b1-py3-none-any.whl.metadata (2.5 kB)
# Collecting pdfminer.six==20250327 (from pdfplumber>=0.11.4->crewai)
#   Downloading pdfminer_six-20250327-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: Pillow>=9.1 in /usr/local/lib/python3.11/dist-packages (from pdfplumber>=0.11.4->crewai) (11.2.1)
# Collecting pypdfium2>=4.18.0 (from pdfplumber>=0.11.4->crewai)
#   Downloading pypdfium2-4.30.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from pdfminer.six==20250327->pdfplumber>=0.11.4->crewai) (3.4.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.4.2->crewai) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.4.2->crewai) (0.4.0)
# Collecting nodeenv>=1.6.0 (from pyright>=1.1.350->crewai-tools)
#   Downloading nodeenv-1.9.1-py2.py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: ipython>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from pyvis>=0.3.2->crewai) (7.34.0)
# Requirement already satisfied: jsonpickle>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from pyvis>=0.3.2->crewai) (4.0.5)
# Requirement already satisfied: networkx>=1.11 in /usr/local/lib/python3.11/dist-packages (from pyvis>=0.3.2->crewai) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->crewai-tools) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->crewai-tools) (2025.4.26)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm==1.68.0->crewai) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm==1.68.0->crewai) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm==1.68.0->crewai) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm==1.68.0->crewai) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm==1.68.0->crewai) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm==1.68.0->crewai) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm==1.68.0->crewai) (1.20.0)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic<2.0.0,>=1.13.1->embedchain>=0.1.114->crewai-tools) (1.1.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4<5.0.0,>=4.12.2->embedchain>=0.1.114->crewai-tools) (2.7)
# Requirement already satisfied: pyproject_hooks in /usr/local/lib/python3.11/dist-packages (from build>=1.0.3->chromadb>=0.5.23->crewai) (1.2.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=43.0.1->auth0-python>=4.7.1->crewai) (1.17.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from deprecated>=1.2.6->opentelemetry-api>=1.30.0->crewai) (1.17.2)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.11/dist-packages (from gptcache<0.2.0,>=0.1.43->embedchain>=0.1.114->crewai-tools) (5.5.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.23.0->litellm==1.68.0->crewai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.23.0->litellm==1.68.0->crewai) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata>=6.8.0->litellm==1.68.0->crewai) (3.21.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (75.2.0)
# Collecting jedi>=0.16 (from ipython>=5.3.0->pyvis>=0.3.2->crewai)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (3.0.51)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (2.19.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2<4.0.0,>=3.1.2->litellm==1.68.0->crewai) (3.0.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.68.0->crewai) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.68.0->crewai) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.68.0->crewai) (0.24.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (2.38.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (3.2.2)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai)
#   Downloading durationpy-0.10-py3-none-any.whl.metadata (340 bytes)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.58 in /usr/local/lib/python3.11/dist-packages (from langchain<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools) (0.3.59)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /usr/local/lib/python3.11/dist-packages (from langchain<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools) (0.3.8)
# Collecting cohere<6.0,>=5.5.6 (from langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools)
#   Downloading cohere-5.15.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting langchain-experimental<0.4.0,>=0.3.0 (from langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools)
#   Downloading langchain_experimental-0.3.4-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: pandas>=1.4.3 in /usr/local/lib/python3.11/dist-packages (from langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools) (2.2.2)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools) (0.9.0)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools)
#   Downloading pydantic_settings-2.9.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools)
#   Downloading httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4.0,>=0.3.18->embedchain>=0.1.114->crewai-tools) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4.0,>=0.3.18->embedchain>=0.1.114->crewai-tools) (0.23.0)
# Requirement already satisfied: pytz>=2024.1 in /usr/local/lib/python3.11/dist-packages (from mem0ai<0.2.0,>=0.1.54->embedchain>=0.1.114->crewai-tools) (2025.2)
# Collecting qdrant-client>=1.9.1 (from mem0ai<0.2.0,>=0.1.54->embedchain>=0.1.114->crewai-tools)
#   Downloading qdrant_client-1.14.2-py3-none-any.whl.metadata (10 kB)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb>=0.5.23->crewai)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.14.1->chromadb>=0.5.23->crewai) (25.2.10)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.14.1->chromadb>=0.5.23->crewai) (1.13.1)
# Collecting opentelemetry-instrumentation-asgi==0.54b1 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai)
#   Downloading opentelemetry_instrumentation_asgi-0.54b1-py3-none-any.whl.metadata (2.1 kB)
# Collecting opentelemetry-instrumentation==0.54b1 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai)
#   Downloading opentelemetry_instrumentation-0.54b1-py3-none-any.whl.metadata (6.8 kB)
# Collecting opentelemetry-util-http==0.54b1 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai)
#   Downloading opentelemetry_util_http-0.54b1-py3-none-any.whl.metadata (2.6 kB)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.54b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai)
#   Downloading asgiref-3.8.1-py3-none-any.whl.metadata (9.3 kB)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb>=0.5.23->crewai)
#   Downloading monotonic-1.6-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb>=0.5.23->crewai)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->chromadb>=0.5.23->crewai) (3.0.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy<3.0.0,>=2.0.27->embedchain>=0.1.114->crewai-tools) (3.2.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.11/dist-packages (from tokenizers->litellm==1.68.0->crewai) (0.31.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer>=0.9.0->chromadb>=0.5.23->crewai) (1.5.4)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai)
#   Downloading httptools-0.6.4-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai)
#   Downloading uvloop-0.21.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai)
#   Downloading watchfiles-1.0.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai) (15.0.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=43.0.1->auth0-python>=4.7.1->crewai) (2.22)
# Collecting fastavro<2.0.0,>=1.9.4 (from cohere<6.0,>=5.5.6->langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools)
#   Downloading fastavro-1.11.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.7 kB)
# Collecting types-requests<3.0.0,>=2.0.0 (from cohere<6.0,>=5.5.6->langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools)
#   Downloading types_requests-2.32.0.20250515-py3-none-any.whl.metadata (2.1 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools)
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (4.9.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm==1.68.0->crewai) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm==1.68.0->crewai) (2025.3.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.8.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.58->langchain<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools) (1.33)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb>=0.5.23->crewai) (0.1.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4.3->langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools) (2025.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.2.13)
# Collecting portalocker<3.0.0,>=2.7.0 (from qdrant-client>=1.9.1->mem0ai<0.2.0,>=0.1.54->embedchain>=0.1.114->crewai-tools)
#   Downloading portalocker-2.10.1-py3-none-any.whl.metadata (8.5 kB)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb>=0.5.23->crewai)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb>=0.5.23->crewai) (1.3.0)
# Requirement already satisfied: h2<5,>=3 in /usr/local/lib/python3.11/dist-packages (from httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai<0.2.0,>=0.1.54->embedchain>=0.1.114->crewai-tools) (4.2.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.58->langchain<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools) (3.0.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (0.6.1)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: hyperframe<7,>=6.1 in /usr/local/lib/python3.11/dist-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai<0.2.0,>=0.1.54->embedchain>=0.1.114->crewai-tools) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /usr/local/lib/python3.11/dist-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai<0.2.0,>=0.1.54->embedchain>=0.1.114->crewai-tools) (4.1.0)
# Downloading crewai-0.121.0-py3-none-any.whl (318 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.6/318.6 kB 14.1 MB/s eta 0:00:00
# Downloading litellm-1.68.0-py3-none-any.whl (7.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 65.5 MB/s eta 0:00:00
# Downloading crewai_tools-0.45.0-py3-none-any.whl (602 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 602.7/602.7 kB 34.0 MB/s eta 0:00:00
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading auth0_python-4.9.0-py3-none-any.whl (135 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.3/135.3 kB 9.7 MB/s eta 0:00:00
# Downloading fastapi-0.115.9-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.9/94.9 kB 7.4 MB/s eta 0:00:00
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 7.9 MB/s eta 0:00:00
# Downloading embedchain-0.1.128-py3-none-any.whl (211 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.3/211.3 kB 16.0 MB/s eta 0:00:00
# Downloading chromadb-0.5.23-py3-none-any.whl (628 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 628.3/628.3 kB 33.8 MB/s eta 0:00:00
# Downloading chroma_hnswlib-0.7.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 67.6 MB/s eta 0:00:00
# Downloading instructor-1.8.3-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.6/94.6 kB 7.0 MB/s eta 0:00:00
# Downloading json_repair-0.46.0-py3-none-any.whl (22 kB)
# Downloading json5-0.12.0-py3-none-any.whl (36 kB)
# Downloading jsonref-1.1.0-py3-none-any.whl (9.4 kB)
# Downloading lancedb-0.22.1-cp39-abi3-manylinux_2_28_x86_64.whl (31.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.8/31.8 MB 45.8 MB/s eta 0:00:00
# Downloading openai-1.75.0-py3-none-any.whl (646 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 647.0/647.0 kB 34.3 MB/s eta 0:00:00
# Downloading opentelemetry_api-1.33.1-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.8/65.8 kB 4.7 MB/s eta 0:00:00
# Downloading opentelemetry_exporter_otlp_proto_http-1.33.1-py3-none-any.whl (17 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.33.1-py3-none-any.whl (18 kB)
# Downloading opentelemetry_proto-1.33.1-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.9/55.9 kB 3.7 MB/s eta 0:00:00
# Downloading opentelemetry_sdk-1.33.1-py3-none-any.whl (118 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.0/119.0 kB 6.7 MB/s eta 0:00:00
# Downloading opentelemetry_semantic_conventions-0.54b1-py3-none-any.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.9/194.9 kB 13.3 MB/s eta 0:00:00
# Downloading pdfplumber-0.11.6-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.2/60.2 kB 4.9 MB/s eta 0:00:00
# Downloading pdfminer_six-20250327-py3-none-any.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 81.5 MB/s eta 0:00:00
# Downloading pyright-1.1.401-py3-none-any.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 65.9 MB/s eta 0:00:00
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Downloading pytube-15.0.0-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 4.3 MB/s eta 0:00:00
# Downloading pyvis-0.3.2-py3-none-any.whl (756 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.0/756.0 kB 10.1 MB/s eta 0:00:00
# Downloading tomli-2.2.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (236 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.0/236.0 kB 13.9 MB/s eta 0:00:00
# Downloading tomli_w-1.2.0-py3-none-any.whl (6.7 kB)
# Downloading uv-0.7.8-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.5/17.5 MB 60.0 MB/s eta 0:00:00
# Downloading alembic-1.16.1-py3-none-any.whl (242 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.5/242.5 kB 14.3 MB/s eta 0:00:00
# Downloading bcrypt-4.3.0-cp39-abi3-manylinux_2_34_x86_64.whl (284 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.2/284.2 kB 16.2 MB/s eta 0:00:00
# Downloading Deprecated-1.2.18-py2.py3-none-any.whl (10.0 kB)
# Downloading gptcache-0.1.44-py3-none-any.whl (131 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.6/131.6 kB 9.1 MB/s eta 0:00:00
# Downloading importlib_metadata-8.6.1-py3-none-any.whl (26 kB)
# Downloading jiter-0.8.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (345 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.6/345.6 kB 19.6 MB/s eta 0:00:00
# Downloading kubernetes-32.0.1-py2.py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 71.9 MB/s eta 0:00:00
# Downloading langchain_cohere-0.3.5-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 kB 2.6 MB/s eta 0:00:00
# Downloading langchain_community-0.3.24-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 66.4 MB/s eta 0:00:00
# Downloading langchain_openai-0.2.14-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.3 MB/s eta 0:00:00
# Downloading mem0ai-0.1.101-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.9/154.9 kB 10.8 MB/s eta 0:00:00
# Downloading mmh3-5.1.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 6.7 MB/s eta 0:00:00
# Downloading nodeenv-1.9.1-py2.py3-none-any.whl (22 kB)
# Downloading onnxruntime-1.22.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 81.8 MB/s eta 0:00:00
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.33.1-py3-none-any.whl (18 kB)
# Downloading opentelemetry_instrumentation_fastapi-0.54b1-py3-none-any.whl (12 kB)
# Downloading opentelemetry_instrumentation-0.54b1-py3-none-any.whl (31 kB)
# Downloading opentelemetry_instrumentation_asgi-0.54b1-py3-none-any.whl (16 kB)
# Downloading opentelemetry_util_http-0.54b1-py3-none-any.whl (7.3 kB)
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading posthog-3.25.0-py2.py3-none-any.whl (89 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.1/89.1 kB 6.3 MB/s eta 0:00:00
# Downloading pypdf-5.5.0-py3-none-any.whl (303 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 303.4/303.4 kB 20.9 MB/s eta 0:00:00
# Downloading pypdfium2-4.30.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 70.2 MB/s eta 0:00:00
# Downloading pysbd-0.3.4-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.1/71.1 kB 5.0 MB/s eta 0:00:00
# Downloading schema-0.7.7-py2.py3-none-any.whl (18 kB)
# Downloading tokenizers-0.20.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 75.8 MB/s eta 0:00:00
# Downloading uvicorn-0.34.2-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 3.5 MB/s eta 0:00:00
# Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading cohere-5.15.0-py3-none-any.whl (259 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.5/259.5 kB 15.2 MB/s eta 0:00:00
# Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading durationpy-0.10-py3-none-any.whl (3.9 kB)
# Downloading httptools-0.6.4-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (459 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 459.8/459.8 kB 20.6 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 55.6 MB/s eta 0:00:00
# Downloading langchain_experimental-0.3.4-py3-none-any.whl (209 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.2/209.2 kB 12.3 MB/s eta 0:00:00
# Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Downloading pydantic_settings-2.9.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 2.5 MB/s eta 0:00:00
# Downloading qdrant_client-1.14.2-py3-none-any.whl (327 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 327.7/327.7 kB 18.4 MB/s eta 0:00:00
# Downloading starlette-0.45.3-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 4.7 MB/s eta 0:00:00
# Downloading uvloop-0.21.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 81.7 MB/s eta 0:00:00
# Downloading watchfiles-1.0.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (454 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 454.8/454.8 kB 25.0 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.6 MB/s eta 0:00:00
# Downloading asgiref-3.8.1-py3-none-any.whl (23 kB)
# Downloading fastavro-1.11.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 83.1 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 5.7 MB/s eta 0:00:00
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.2 MB/s eta 0:00:00
# Downloading portalocker-2.10.1-py3-none-any.whl (18 kB)
# Downloading types_requests-2.32.0.20250515-py3-none-any.whl (20 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=pypika-0.48.9-py2.py3-none-any.whl size=53801 sha256=57f3178cde9d776ff3521878b166ab9e94e05c474e3bd8817ca7c864a0bfbfed
#   Stored in directory: /root/.cache/pip/wheels/a3/01/bd/4c40ceb9d5354160cb186dcc153360f4ab7eb23e2b24daf96d
# Successfully built pypika
# Installing collected packages: schema, pypika, monotonic, durationpy, appdirs, uvloop, uvicorn, uv, types-requests, tomli-w, tomli, pytube, python-dotenv, pysbd, pypdfium2, pypdf, portalocker, overrides, opentelemetry-util-http, opentelemetry-proto, nodeenv, mypy-extensions, mmh3, marshmallow, jsonref, json5, json-repair, jiter, jedi, importlib-metadata, humanfriendly, httpx-sse, httptools, fastavro, deprecation, deprecated, chroma-hnswlib, bcrypt, backoff, asgiref, watchfiles, typing-inspect, starlette, pyright, posthog, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, gptcache, docker, coloredlogs, alembic, tokenizers, pyvis, pydantic-settings, pdfminer.six, opentelemetry-semantic-conventions, openai, onnxruntime, lancedb, kubernetes, fastapi, dataclasses-json, auth0-python, qdrant-client, pdfplumber, opentelemetry-sdk, opentelemetry-instrumentation, litellm, instructor, cohere, opentelemetry-instrumentation-asgi, opentelemetry-exporter-otlp-proto-http, opentelemetry-exporter-otlp-proto-grpc, mem0ai, langchain-openai, opentelemetry-instrumentation-fastapi, langchain-community, chromadb, langchain-experimental, crewai, langchain-cohere, embedchain, crewai-tools
#   Attempting uninstall: jiter
#     Found existing installation: jiter 0.9.0
#     Uninstalling jiter-0.9.0:
#       Successfully uninstalled jiter-0.9.0
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib_metadata 8.7.0
#     Uninstalling importlib_metadata-8.7.0:
#       Successfully uninstalled importlib_metadata-8.7.0
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.21.1
#     Uninstalling tokenizers-0.21.1:
#       Successfully uninstalled tokenizers-0.21.1
#   Attempting uninstall: openai
#     Found existing installation: openai 1.78.1
#     Uninstalling openai-1.78.1:
#       Successfully uninstalled openai-1.78.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# transformers 4.51.3 requires tokenizers<0.22,>=0.21, but you have tokenizers 0.20.3 which is incompatible.
# Successfully installed alembic-1.16.1 appdirs-1.4.4 asgiref-3.8.1 auth0-python-4.9.0 backoff-2.2.1 bcrypt-4.3.0 chroma-hnswlib-0.7.6 chromadb-0.5.23 cohere-5.15.0 coloredlogs-15.0.1 crewai-0.121.0 crewai-tools-0.45.0 dataclasses-json-0.6.7 deprecated-1.2.18 deprecation-2.1.0 docker-7.1.0 durationpy-0.10 embedchain-0.1.128 fastapi-0.115.9 fastavro-1.11.1 gptcache-0.1.44 httptools-0.6.4 httpx-sse-0.4.0 humanfriendly-10.0 importlib-metadata-8.6.1 instructor-1.8.3 jedi-0.19.2 jiter-0.8.2 json-repair-0.46.0 json5-0.12.0 jsonref-1.1.0 kubernetes-32.0.1 lancedb-0.22.1 langchain-cohere-0.3.5 langchain-community-0.3.24 langchain-experimental-0.3.4 langchain-openai-0.2.14 litellm-1.68.0 marshmallow-3.26.1 mem0ai-0.1.101 mmh3-5.1.0 monotonic-1.6 mypy-extensions-1.1.0 nodeenv-1.9.1 onnxruntime-1.22.0 openai-1.75.0 opentelemetry-api-1.33.1 opentelemetry-exporter-otlp-proto-common-1.33.1 opentelemetry-exporter-otlp-proto-grpc-1.33.1 opentelemetry-exporter-otlp-proto-http-1.33.1 opentelemetry-instrumentation-0.54b1 opentelemetry-instrumentation-asgi-0.54b1 opentelemetry-instrumentation-fastapi-0.54b1 opentelemetry-proto-1.33.1 opentelemetry-sdk-1.33.1 opentelemetry-semantic-conventions-0.54b1 opentelemetry-util-http-0.54b1 overrides-7.7.0 pdfminer.six-20250327 pdfplumber-0.11.6 portalocker-2.10.1 posthog-3.25.0 pydantic-settings-2.9.1 pypdf-5.5.0 pypdfium2-4.30.1 pypika-0.48.9 pyright-1.1.401 pysbd-0.3.4 python-dotenv-1.1.0 pytube-15.0.0 pyvis-0.3.2 qdrant-client-1.14.2 schema-0.7.7 starlette-0.45.3 tokenizers-0.20.3 tomli-2.2.1 tomli-w-1.2.0 types-requests-2.32.0.20250515 typing-inspect-0.9.0 uv-0.7.8 uvicorn-0.34.2 uvloop-0.21.0 watchfiles-1.0.5

# %% [markdown]
# # **2. Setting up Environment**

# %%
from crewai import Agent, Task, Crew, Process
import os
from crewai.knowledge.source.text_file_knowledge_source import TextFileKnowledgeSource

# %%
# Set your OpenAI API key as an environment variable so that the respective tools can access it.
# (NOTE: The API key is left empty for security; insert your own if running this code.)
os.environ['OPENAI_API_KEY'] = ""

# %% [markdown]
# # **3. Setting Up Tool for Image Generation**

# %%
import json
import uuid
import os
from typing import Type

from crewai.tools import BaseTool
from openai import OpenAI
from pydantic import BaseModel

# Define input validation schema for the DALL·E image generation tool.
# Ensures the prompt/description is a non-empty string.
class DalleImagePromptSchema(BaseModel):
    """Input schema for DALL·E Tool."""
    description: str = "Description of the image to be generated by the DALL·E model."

# Custom tool for image generation using OpenAI's DALL·E model.
class DalleImageTool(BaseTool):
    name: str = "DALL·E Image Tool"
    description: str = "Generates images using OpenAI's DALL·E model."
    args_schema: Type[BaseModel] = DalleImagePromptSchema

    model: str = "dall-e-3"
    size: str = "1024x1024"
    n: int = 1
    quality: str = "standard"  # or "hd" if available

    def _run(self, **kwargs) -> str:
        client = OpenAI()

        prompt: str = kwargs.get("description")
        if not prompt:
            return "Image description is required."

        response = client.images.generate(
            model=self.model,
            prompt=prompt,
            size=self.size,
            quality=self.quality,
            n=self.n,
            response_format="url"
        )

        image_url = response.data[0].url

        return json.dumps({
            "prompt": prompt,
            "image_url": image_url
        })

# %% [markdown]
# # **3. Setting Up Tool for Backstory Generation**

# %%
import os
from openai import OpenAI
from crewai.tools import BaseTool
from pydantic import BaseModel

# Input schema for the backstory generator tool (expects a refined prompt)
class BackstoryPromptSchema(BaseModel):
    """Schema for the backstory generator."""
    refined_prompt: str = "The refined avatar prompt or user description."

# Custom tool for generating character backstories using GPT-4
class BackstoryGeneratorTool(BaseTool):
    name: str = "Avatar Backstory Generator"
    description: str = (
        "Takes a refined avatar prompt and returns a rich, 200–300 word backstory "
        "covering origins, key events, personality, and cultural background."
    )
    args_schema: type[BaseModel] = BackstoryPromptSchema

    def _run(self, **kwargs) -> str:
        prompt = kwargs.get("refined_prompt")
        if not prompt:
            return "A refined prompt is required to generate a backstory."
        # system is how gpt should behave to write the backstory of generated character
        system = (
            "You are a master storyteller and world‑builder. "
            "Your task is to breathe life into characters by weaving together "
            "plot threads, cultural details, and emotional arcs."
        )
        # user tells  what user is expecting and what would output look like
        user = (
            f"Generate a vivid backstory (200–300 words) for an avatar described as:\n\n"
            f"{prompt}\n\n"
            "Cover:\n"
            "1. Origins and heritage\n"
            "2. Key life events or turning points\n"
            "3. Core personality traits and motivations\n"
            "4. Cultural influences or traditions\n"
            "Tie the narrative to visual elements implied by the prompt."
        )

        # Instantiate client inside the run method
        client = OpenAI()

        response = client.chat.completions.create(
            model="gpt-4",
            messages=[
                {"role": "system", "content": system},
                {"role": "user", "content": user}
            ]
        )
        return response.choices[0].message.content

# %% [markdown]
# # **5. Agents Structure and setting up pipeline**

# %%
# Loads a knowledge base from given text files. This base will inform the research agent.
text_source = TextFileKnowledgeSource(
    file_paths=["g1.txt", "g2.txt", "marshal.txt", "thesis.txt"],
)
# Define the agents, each with a specialized role and backstory for context-aware processing.
research_agent = Agent(
    role="Research Agent",
    goal="Analyze the provided knowledge_base and extract historical and cultural details on the Gandhara "
         "civilization to inform design of user prompt: {prompt}.",
    backstory="You are a domain expert on ancient Gandhara and Taxila, familiar with archaeological sources like Sir "
              "John Marshall and museum archives.",
    knowledge_sources=[text_source],
    verbose=True,
    memory=False,
)

prompt_refiner_agent = Agent(
    role="Prompt Engineer",
    goal="Transform the user's raw description into a culturally informed, high-quality prompt suitable for image "
         "generation by applying best practices and avoiding common pitfalls.",
    backstory="You are a prompt engineering specialist skilled at designing text prompts for artistic AI models.",
    verbose=True,
    memory=False,
)

avatar_generator_agent = Agent(
    role="Avatar Generator",
    goal="Generate one or more artistic avatars based on the refined prompt, using a text-to-image model.",
    backstory="You are an AI image generation system that creates avatars in the Greco-Buddhist style of Gandhara.",
    verbose=True,
    memory=False,
)

backstory_generator_agent = Agent(
    role="Storyteller",
    goal=(
        "Take a refined avatar prompt and spin up an emotionally engaging, "
        "culturally rich backstory that brings the character to life."
    ),
    backstory="You are a master storyteller and world‑builder.",
    tool=BackstoryGeneratorTool(),  # singular, not a list
    verbose=True,
    memory=False,
)

research_task = Task(
    description="Research historical and cultural context on Gandhara using the provided knowledge base and initial "
                "user prompt: {prompt}.",
    expected_output="A summary of key Gandharan artistic and cultural elements.",
    agent=research_agent,
)

refine_prompt_task = Task(
    description="Refine the user prompt into a detailed, art-style-aware prompt using the research summary, "
                "good prompts are: {good_prompts}\n, and bad_prompts are: {bad_prompts}.\n"
                "Make sure the refined prompt should focus on making avatar not the environment.",
    expected_output="A refined image-generation prompt.",
    agent=prompt_refiner_agent,
)

generate_avatar_task = Task(
    description="Generate Gandharan-style avatars based on the refined prompt using the Dalle2 text-to-image tool provided.",
    expected_output="URLs or binary blobs of generated avatar images.",
    agent=avatar_generator_agent,
    tools=[DalleImageTool()]
)


generate_backstory_task = Task(
    description=(
        "Feed the refined avatar prompt into the backstory generator tool "
        "to produce a standalone narrative of ~200–300 words."
    ),
    expected_output="A compelling backstory for the generated avatar.",
    agent=backstory_generator_agent,
)
# Crew: Orchestrates the agents and tasks as a pipeline (sequential execution).
crew = Crew(
    agents=[research_agent, prompt_refiner_agent, avatar_generator_agent,backstory_generator_agent],
    tasks=[research_task, refine_prompt_task, generate_avatar_task,generate_backstory_task],
    process=Process.sequential,
)

# Utility function to read sample prompt files (good and bad examples for reference).
def read_prompts(prompts_path):
    with open(prompts_path, "r", encoding="utf-8") as f:
        prompts = f.read()

    return prompts

# %% [markdown]
# # **6. Implementation**

# %%
path = "knowledge"
good_prompts = read_prompts(os.path.join(path, "good_prompts.txt"))
bad_prompts = read_prompts(os.path.join(path, "bad_prompts.txt"))
# Prepare initial user input and reference prompt examples.
inputs = {
    "prompt": "Gandharan warrior, realistic avatar.",
    "good_prompts": good_prompts,
    "bad_prompts": bad_prompts
}
# Run the full pipeline: research, refine prompt, generate avatar, generate backstory.
result = crew.kickoff(inputs=inputs)
# Output the end result of the pipeline (likely includes image URLs and the avatar's backstory).
print(result)
# Out:
# # Agent: Research Agent
# ## Task: Research historical and cultural context on Gandhara using the provided knowledge base and initial user prompt: Gandharan warrior, realistic avatar..
#
#
# # Agent: Research Agent
# ## Final Answer:
# The Gandhara civilization, flourishing from approximately the 5th century BCE to the 5th century CE, is renowned for its unique blend of artistic and cultural elements that reflect a fusion of Hellenistic, Persian, Central Asian, and indigenous Indian influences. This cultural synthesis is vividly illustrated in their sculptures, architecture, and artifacts, especially in the region of Taxila and other sites across ancient Gandhara.
#
# 1. **Artistic Style**: Gandharan art is characterized by its realistic portrayals of figures, drapery, and expressions, often depicting Buddhist themes. The artists focused on human anatomy, showcasing detailed musculature and lifelike features. This was a departure from earlier Indian art, which was more stylized. Notably, the figures often wore Greco-Roman garments, which demonstrates the cross-cultural interactions in Gandhara.
#
# 2. **Buddhist Iconography**: The most prominent subject matter in Gandharan art is Buddhism, particularly the life of the Buddha and key Buddhist symbols. The sculptures often depict the Buddha in various mudras (hand gestures) that carry specific meanings, such as meditation or teaching. Bodhisattvas and previous incarnations of the Buddha are also commonly represented, featuring elaborate adornments and intricate details that highlight their divine status.
#
# 3. **Architectural Elements**: Gandharan architecture is evidenced in stupas and monastic complexes. The Dharmarajika Stupa and the towering stupa at Butkara are examples of monumental structures that served as reliquaries. These stupas often feature intricate stone carvings that narrate Jataka tales (stories of the Buddha’s previous lives) around their bases and are crowned with hemispherical domes that symbolize the cosmic universe.
#
# 4. **Sculptural Techniques**: The stone-carving techniques utilized by Gandharan artisans involved high relief and intricate ornamental detail. The use of schist and limestone allowed for fine carving, resulting in the dramatic play of light and shadow across the surfaces of sculptures. This technique became a hallmark of Gandharan artistry, giving the works a dynamic quality.
#
# 5. **Cultural Context**: The Gandhara region served as a crucial crossroad for trade and cultural exchange, located along the Silk Road. This trade brought diverse influences into Gandharan society, contributing to its rich tapestry of artistic styles. The region was home not only to Buddhists but also to Zoroastrians and Hellenistic cultures, lending a multiplicity of perspectives and aesthetics to its art.
#
# 6. **Warrior Depictions**: The representation of warriors, particularly in the context of Buddhist themes, showcases Gandharan artistic innovation. Warriors are often depicted in combat or protective stances, wearing helmets and armor reflective of both local and Hellenistic designs. Their muscular forms convey strength, and they are sometimes shown alongside divine figures, signaling their role as protectors of dharma (cosmic law).
#
# In designing a realistic avatar of a Gandharan warrior, one would capture these essential elements: the detailed musculature and dynamic poses typical of Gandharan art, the intricate armor that reflects cultural exchanges, and the depiction of weapons and attributes that signify their status and role in society. The avatar should embody the rich cultural legacy of Gandhara, incorporating not just physical features but also the spiritual significance of the figures within the context of Buddhist narratives. This holistic approach will resonate well with the historical authenticity and artistic values inherent in the Gandharan civilization.
#
#
# # Agent: Prompt Engineer
# ## Task: Refine the user prompt into a detailed, art-style-aware prompt using the research summary, good prompts are: 1- "Prompt for Midjourney / DALL·E / Stable Diffusion:
#
# “Create a clean, square infographic (1:1 ratio, 2048×2048 px).
# • Background: soft off-white (#F7F8F4).
# • Top banner: full-width matte black bar, 20 % of canvas height. Centered large bold white text inside banner:
#   ‘SHRED your meal plan in 2025!’ (all-caps for ‘SHRED’, sentence case for the rest).
# • Below, split the remaining area into two equal vertical panels with a thin black dividing line.
#
# Left panel (light background):
#   – Title near top, stacked in two lines, all-caps, heavy sans-serif:
#     ‘THE
#      OLD WAY’
#   – Under the title, list 12 bullet points, each preceded by a red emoji-style ‘X’ icon:
#     1. Hunt for recipes
#     2. Shop for groceries
#     3. Spend hours prepping
#     4. Overcook and underseason
#     5. Tons of dishes
#     6. Ingredients go bad
#     7. Grocery shop AGAIN
#     8. Hire a dietitian
#     9. Feel hungry all the time
#     10. Give up and binge
#     11. Try again
#
# Right panel (light background):
#   – Top title: word-spaced, monospaced, bold black letters:
#     ‘USING
#      F A C T O R _’
#   – Two benefit bullets, each preceded by a large green check-mark:
#     • ‘Get dietitian-approved meals delivered!’
#     • ‘Get 50 % off!!’ with smaller sub-text directly beneath: ‘+ 20 % off next month’ in lighter weight.
#   – Bottom-right corner: a bright red angled coupon sticker reading ‘YUMFB50’, outlined in white, with the phrase ‘Use code:’ above it in charcoal gray playful script. A small curved black arrow points up toward the coupon.
#
# Typography: modern geometric sans-serif (e.g., Montserrat or Inter, extra-bold for headings, regular for body).
# Color palette: black, white, off-white (#F7F8F4), red (#FF4757), green (#00B140).
# Flat design, high contrast, no gradients, no drop shadows.”"
#
# 2- "Prompt for an image-generation model (adjust style keywords to suit your preferred engine):
#
# “Top-down, high-resolution food-advertisement. A light, warm-oak wooden tabletop fills the background. Centered are nine black, microwave-style meal-prep trays arranged in a neat 3×3 grid. Each tray has 2–4 compartments showing vibrant, healthy food:
#   • roasted chickpeas on kale and rice
#   • garlic shrimp on greens
#   • herbed chicken breast over sliced potatoes
#   • steamed broccoli, green beans with cherry tomatoes, corn salsa, brown rice, etc.
# Bright, natural window light from the upper left creates soft shadows.
#
# Text overlays:
# 1. Near the very top, a wide black rounded-rectangle banner with the slogan:
#    “End 2024 by eating BETTER” — all caps, white sans-serif, but the word “BETTER” in bold, vivid red.
# 2. Toward the lower third, playful tilted headline reading:
#    “Try FACTOR –” (white text inside a narrow black bar)
#    beneath that, larger text: “with 50% OFF” (the “50% OFF” in bright red)
#    followed by “your first box!” in white.
# 3. A hand-drawn style curved arrow sweeps up from the bottom right corner toward the offer text.
#
# Overall mood: crisp, appetizing, modern, clean layout suitable for a healthy-meal subscription ad.”"
#
# 3- "PROMPT FOR AN IMAGE-GENERATION MODEL
# (as if for Midjourney / Stable Diffusion)
#
# “Clean, square (1:1) advertising layout on a pure white background.
# • Top-left: the word ‘FACTOR_’ in large, tight-kerned, black, modern sans-serif caps, trailing underscore, generous tracking.
# • Directly beneath it, two-line tagline ‘NO HASSLE / NUTRITION’ in bold uppercase; black letters with thick yellow stroke/fill outline so the text appears black-centered with a bright yellow halo.
# • Bottom-left quadrant: a realistic, high-resolution black three-compartment microwave-meal tray photographed from straight above.
#  – Top-left cell: small round cup of creamy beige dressing.
#  – Top-right cell: vivid steamed broccoli florets.
#  – Large bottom cell: colourful mix of roasted orange chickpeas, diced tomato, wilted kale over a bed of whole-grain rice.
# • Top-right quadrant: a second realistic black two-compartment meal tray, same angle.
#  – Upper section: golden-brown grilled chicken breast resting on round sliced roasted potatoes, light pepper seasoning.
#  – Lower section: bright green beans with a few glossy red cherry-tomato halves.
# • Center-right overlay text block, bold and punchy:
#  “FACTOR IS OFFERING” (small black caps)
#  “50% OFF” (very large, black letters with thick yellow outline)
#  “YOUR FIRST BOX” (smaller black caps)
#  Black horizontal bar beneath with “+20% OFF” in big yellow caps inside the bar.
#  “YOUR NEXT MONTH” in black caps under the bar.
# • Bottom-right: “Use code:” in small black type, and large bold ‘YUMFB50’ in yellow with black outline.
# • Subtle soft shadows under the trays to give slight depth; otherwise minimalistic, high-contrast, food-photography realism, bright lighting, crisp focus, vibrant colors.”
#
# END"
#
# 4- "Prompt for a commercial-style food advertisement (portrait orientation):
#
# “High-resolution studio photo, soft beige background. Center frame: two medium-brown hands raised from the bottom edge, holding a neat stack of three glossy black meal-prep containers. The top tray has no lid, showing a juicy filet-mignon patty resting on creamy mashed potatoes in the left compartment and herb-roasted, orange carrots in the right compartment. On the visible sides of the lower two trays, a clean white sans-serif slogan reads ‘Fitness starts with food.’ Bright, even lighting, crisp focus, vibrant food colors, slight top-down angle. In the lower half of the poster, bold headline text in black with thick yellow outline: ‘GET 50% OFF YOUR FIRST BOX + 20% OFF YOUR NEXT MONTH,’ followed by smaller black text ‘Use code:’ and large yellow code ‘YUMFB50.’ Modern meal-delivery advertisement, appetizing and eye-catching.”"
#
# 5- "Prompt for an AI image-generator:
#
# “Design a square, social-media style promo graphic on a soft lavender-gray marble background.
# • Text header (top center): ‘GET 50% OFF YOUR 1ST BOX OF’ — uppercase, bold white letters with a thick black outline.
# • Directly under it, much larger bubble lettering: ‘NO HASSLE NUTRITION’ — bright aqua/cyan gradient fill, heavy black outline, slight cartoony tilt.
# • Mid-section product shot: a neat horizontal stack of five black, sleeve-wrapped meal containers; on top/front, a minimalist white sleeve that reads ‘FACTOR’ in clean black sans-serif.
# • Beneath the stack, two open black meal trays angled outward:
#    – Left tray: grilled chicken breast over mashed cauliflower, side of vibrant green beans.
#    – Right tray: creamy broccoli florets in one compartment, pasta topped with roasted cherry tomatoes and feta in the other.
# • Subtle drop shadows under each tray for depth.
# • Lower text block:
#    – Line 1: ‘TRY THE’ — bold white uppercase, black outline.
#    – Line 2 (largest): ‘GLP-1 BALANCE’ — vivid golden-yellow fill, thick black outline, eye-catching.
#    – Line 3: ‘MEALS NOW!’ — white uppercase, black outline.
# • Bottom-right: a simple hand-drawn curved arrow (black with white stroke) pointing up toward the trays.
# • Overall style: crisp, vibrant, high-contrast commercial look; photo-realistic food combined with flat, outlined 2-D text elements; clean, balanced composition.”"
#
#
# , and bad_prompts are: 1- "Prompt for a design/AI-image-generation tool:
#
# “Square social-media ad with a dark, almost-black charcoal background.
#
# 1. Centered at the very top, a small minimalist wordmark in thin white sans-serif: ‘F A C T O R _’.
# 2. Beneath it, huge, bold, all-caps white text (three lines, flush-center):
#    WANT TO LOSE 2.6" OFF
#    YOUR WAIST IN 16 WEEKS?*
#
# 3. Slightly lower and left-of-center, a realistic 2-compartment black meal tray tilted about 20° toward the viewer.
#    • Top compartment: vibrant green broccoli with a pat of butter.
#    • Bottom compartment: grilled chicken breast topped with glossy roasted cherry tomatoes.
#    • Subtle reflection and soft shadow to make it pop off the background.
#
# 4. To the right of the tray, three short bullet claims stacked in white bold text, each line-breaked:
#    ~ 550-CALORIE
#    MEALS
#
#    HEAT AND EAT
#    IN 2 MINUTES
#
#    40 WEEKLY
#    MENU OPTIONS
#
# 5. Near the bottom center, massive white text:
#    GET 50% OFF
#    (next line, smaller but still bold) YOUR FIRST BOX
#
# 6. Directly under that, a line in white: WITH CODE: followed by a vivid yellow rounded rectangle label containing black bold text ‘YUMMY50SMART’.
#
# 7. Very bottom edge, tiny white disclaimer text:
#    *WITH FACTOR CALORIE SMART, BASED ON A RANDOMIZED-CONTROLLED CLINICAL TRIAL. NOT A WEIGHT LOSS PLAN; RESULTS WILL VARY DEPENDING ON DIET AND EXERCISE.
#
# Clean, high contrast, modern sans-serif fonts, generous letter-spacing, and equal margins all around.”"
#
# 2- "Prompt (ready to drop into Midjourney / Stable Diffusion):
#
# “Square-format (1:1) food-advertisement photo. Foreground: a black, three-compartment microwave meal tray on a wooden table, shot at a 45-degree angle with shallow depth of field. Front-right compartment: six garlic-herb shrimp on a bed of sautéed kale, glistening with butter and pepper. Front-left compartment: small clear ramekin of creamy ranch dipping sauce with cracked-pepper garnish. Rear-left compartment: colorful diced vegetable medley (zucchini, red bell pepper, purple onion). Background: multiple slightly blurred, identical black meal trays containing lemon-herb chicken breast, green beans, chickpea dishes, etc.
#
# Lighting & style: bright, natural window light from the right, cinematic highlights, vibrant color grading, 4-K commercial food-photography look, crisp details on the shrimp, bokeh in the background.
#
# Overlay text (bold, clean sans serif):
# • Upper left: gigantic yellow “2”, stacked yellow text beside/under it: “MINUTE MEALS” (all caps, thick drop shadow).
# • Upper right, white & yellow text in stacked lines:
#    “GET
#     50% OFF
#     YOUR FIRST BOX
#     + 20% OFF
#     YOUR NEXT MONTH”
# • Just below that, medium white text: “Use code:”
# • Prominent yellow-outlined code: “YUMFB50”.
# • Bottom left corner, small white logo text: “FACTOR_”.
#
# Overall mood: energetic, healthy, convenient, premium meal-prep service advertisement."
#
# 3- "Prompt for a text-to-image model (e.g., Midjourney / DALL·E)
#
# “An eye-catching digital ad with a bold, high-contrast layout on a solid black background.
# Top center: large, white all-caps headline reading ‘PICK YOUR’ on one line and beneath it an even larger, bright-coral all-caps line reading ‘GLP-1 SUPPORT’; third line in white: ‘MEAL PLAN’.
# Below the headline, two portrait-oriented photo panels sit side-by-side, each framed by a thick yellow rounded rectangle:
#
# • Left panel: desaturated, dull image of a clear plastic meal-prep container holding a single bland boiled chicken breast and a few cauliflower florets, container resting on a digital kitchen scale (display shows 211 g). Text at the top of this panel in bold, coral, playful font with black stroke: ‘THAT?’.
# • Right panel: vibrant, appetizing photo of a black two-compartment microwavable tray. Top compartment filled with bright green roasted broccoli sprinkled with grated parmesan; bottom compartment contains colorful pasta tossed with roasted cherry tomatoes and crumbled feta. Text at the top of this panel in bold, coral font with black stroke: ‘THIS!’.
#
# Centered between the two panels: a coral-red circular badge with white outline and the word ‘OR’ in large white letters.
#
# Bottom of the poster: promotional call-to-action text on two lines. First line in white sentence case: ‘Get’, followed by ‘50% off’ in coral bold, then the rest of the sentence in white: ‘your 1st box of’. Second line entirely coral: ‘Factor’s GLP-1 Balance meals!’ Use a clean, modern sans-serif typeface throughout (similar to Montserrat or Helvetica Neue).
#
# Overall styling: high resolution, sharp detail, professional ad design, balanced spacing, strong color contrast, no people present.”"
#
# 4- "PROMPT
# “High-resolution, flat-lay food advertising graphic. Background: warm cream-colored studio backdrop with strong, directional overhead lighting that casts crisp shadows. Center-right: two black, three-compartment microwavable meal trays held by two different hands entering from opposite sides. Top tray: spicy red-seasoned salmon over creamy rice, roasted broccoli and sweet-potato mash. Bottom tray: zucchini-noodle pasta with meatballs in red marinara and shredded parmesan, plus a large portion of vibrant steamed broccoli. Upper-left corner: minimalist logotype in bold black sans-serif capitals reading ‘FACTOR_’. Beneath the logo, two stacked lines of coral-red text: ‘NO HASSLE’ / ‘NUTRITION’. Lower-right quadrant: promotional copy in clean sans-serif fonts— first line small black caps: ‘FACTOR IS OFFERING’, second line slightly larger: ‘UP TO’. Below, a thick black rectangle containing huge coral-red ‘$130’ followed by white ‘OFF’. Underneath, smaller text: ‘Use code:’ in black, and a large coral-red coupon code ‘YUM130OFF’. Modern, high-contrast, appetizing, magazine-style composition.”"
#
# 5- "Prompt (text-to-image)
#
# “Square, top-down food-ad style photo shot on a bright marble countertop. Center frame: a black, two-compartment microwave meal tray. • Left compartment: grilled chicken breast with light char marks, smothered in creamy peanut-colored sauce, sprinkled with a few black sesame seeds, resting on a bed of vibrant orange spiralized sweet-potato noodles. • Right compartment: crunchy chopped salad—shredded green lettuce, purple cabbage ribbons, thin carrot sticks, red bell-pepper strips, and scattered roasted almond slivers—fresh and colorful. Overlay graphics (clean, modern marketing look): • Top-left corner: small black square logo with minimalist white “F_”. • Angled coral-pink banner across upper center reading: “UP TO $130 OFF” in bold white caps, smaller white text above it: “Try Factor for”. A playful white doodle arrow points down toward the food. • Bottom-right: another coral-pink rounded rectangle reading “YUM130OFF” in bold white caps, above it in white outline text with black shadow: “Use code:”. Small curved white arrow beside it. Lighting: bright, natural side-light from upper left creating soft shadows, crisp focus, appetizing color saturation, subtle reflections on the plastic tray, realistic texture details. High-resolution commercial food photography aesthetic.”"
#
# .
# Make sure the refined prompt should focus on making avatar not the environment.
#
#
# # Agent: Prompt Engineer
# ## Final Answer:
# "Create a highly detailed and realistic avatar of a Gandharan warrior, emphasizing intricate musculature and dynamic poses characteristic of Gandharan art. The warrior should be depicted in an action pose, wearing ornate armor that reflects a blend of local and Hellenistic designs, featuring elements such as a helmet with decorative motifs and a breastplate showing fine craftsmanship.
#
# Incorporate weapons typical of the era, such as a curved sword and a shield adorned with intricate carvings that signify strength and protectiveness. The avatar's expression should convey bravery and determination, capturing the spiritual significance associated with warriors in Buddhist narratives.
#
# Use a color palette that reflects the earthy tones of schist and limestone, imbuing the armor with textures that suggest light interplay. The depiction should include cultural attributes that resonate with the Buddhist theme, perhaps showing the warrior alongside symbols of dharma or protected relics. Ensure the overall composition reflects the rich cultural legacy of the Gandhara civilization and its artistic values, highlighting not just the physicality of the figure but also its connection to Buddhist iconography and the historical significance of the warrior's role as a protector of dharma."
#
#
# # Agent: Avatar Generator
# ## Task: Generate Gandharan-style avatars based on the refined prompt using the Dalle2 text-to-image tool provided.
#
#
# # Agent: Avatar Generator
# ## Thought: Thought: I will generate a highly detailed and realistic avatar of a Gandharan warrior based on the provided refined prompt.
# ## Using tool: DALL·E Image Tool
# ## Tool Input:
# "{\"description\": \"Create a highly detailed and realistic avatar of a Gandharan warrior, emphasizing intricate musculature and dynamic poses characteristic of Gandharan art. The warrior should be depicted in an action pose, wearing ornate armor that reflects a blend of local and Hellenistic designs, featuring elements such as a helmet with decorative motifs and a breastplate showing fine craftsmanship. Incorporate weapons typical of the era, such as a curved sword and a shield adorned with intricate carvings that signify strength and protectiveness. The avatar's expression should convey bravery and determination, capturing the spiritual significance associated with warriors in Buddhist narratives. Use a color palette that reflects the earthy tones of schist and limestone, imbuing the armor with textures that suggest light interplay. The depiction should include cultural attributes that resonate with the Buddhist theme, perhaps showing the warrior alongside symbols of dharma or protected relics. Ensure the overall composition reflects the rich cultural legacy of the Gandhara civilization and its artistic values.\"}"
# ## Tool Output:
# {"prompt": "Create a highly detailed and realistic avatar of a Gandharan warrior, emphasizing intricate musculature and dynamic poses characteristic of Gandharan art. The warrior should be depicted in an action pose, wearing ornate armor that reflects a blend of local and Hellenistic designs, featuring elements such as a helmet with decorative motifs and a breastplate showing fine craftsmanship. Incorporate weapons typical of the era, such as a curved sword and a shield adorned with intricate carvings that signify strength and protectiveness. The avatar's expression should convey bravery and determination, capturing the spiritual significance associated with warriors in Buddhist narratives. Use a color palette that reflects the earthy tones of schist and limestone, imbuing the armor with textures that suggest light interplay. The depiction should include cultural attributes that resonate with the Buddhist theme, perhaps showing the warrior alongside symbols of dharma or protected relics. Ensure the overall composition reflects the rich cultural legacy of the Gandhara civilization and its artistic values.", "image_url": "https://oaidalleapiprodscus.blob.core.windows.net/private/org-ybgfZAfPvNFmGuAWy7dY5dQP/user-idphWuZxJ2ooewScAG7mnbuB/img-EdmXAGjl0jRbJcnfWFfvW2Js.png?st=2025-05-25T06%3A56%3A55Z&se=2025-05-25T08%3A56%3A55Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=475fd488-6c59-44a5-9aa9-31c4db451bea&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-05-25T05%3A15%3A16Z&ske=2025-05-26T05%3A15%3A16Z&sks=b&skv=2024-08-04&sig=at2XltZn6PN1qmE0MDU9YtjxpdvldlsCsBJbI8vF0jI%3D"}
#
#
# # Agent: Avatar Generator
# ## Final Answer:
# {"image_url": "https://oaidalleapiprodscus.blob.core.windows.net/private/org-ybgfZAfPvNFmGuAWy7dY5dQP/user-idphWuZxJ2ooewScAG7mnbuB/img-EdmXAGjl0jRbJcnfWFfvW2Js.png?st=2025-05-25T06%3A56%3A55Z&se=2025-05-25T08%3A56%3A55Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=475fd488-6c59-44a5-9aa9-31c4db451bea&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-05-25T05%3A15%3A16Z&ske=2025-05-26T05%3A15%3A16Z&sks=b&skv=2024-08-04&sig=at2XltZn6PN1qmE0MDU9YtjxpdvldlsCsBJbI8vF0jI%3D"}
#
#
# # Agent: Storyteller
# ## Task: Feed the refined avatar prompt into the backstory generator tool to produce a standalone narrative of ~200–300 words.
#
#
# # Agent: Storyteller
# ## Final Answer:
# The warrior, known as Akar, was born in the vibrant city of Taxila, the heart of the Gandhara civilization, around 170 CE. Son of a revered sculptor, Akar grew up among the masterpieces of art that adorned the stupas and monastic complexes dotting the landscape. His father imbued in him a passion for the arts, but Akar's heart leaned towards the call of valor and the dharma he had learned from the teachings of Buddhism.
#
# As a youth, Akar was mesmerized by tales of the Buddha’s past lives, recounting not just supernatural ascensions but also earthly battles against ignorance and evil. His training began early; he was tutored in martial skills by the seasoned warriors who protected the sacred relics of the stupas. It wasn’t long before he became a formidable figure, his physique sculpted from rigorous training, reminiscent of the very statues he admired. Muscles rippling, he wore armor that blended local craftsmanship with Hellenistic designs, embodying the rich cultural exchanges that marked his nation.
#
# Akar fought bravely in various skirmishes against marauding tribes threatening the sanctity of their land. Dressed in ornate armor, decorated with motifs symbolizing protection and strength, he wielded a beautifully curved sword—a family heirloom—as well as a shield that bore intricate carvings of celestial beings. His expression was one of determination and bravery, channeling the energy of the Bodhisattvas he aspired to emulate.
#
# In the quiet moments after battle, Akar often found solace by the stupas, engaging in meditation to reflect on the balance between the warrior’s path and the teachings of compassion. He understood that the true essence of being a protector was not solely in physical strength but in upholding the values of peace and enlightenment. Akar thus became a living embodiment of Gandharan artistry and spirituality, a warrior not just in combat, but in the unwavering pursuit of wisdom and truth that resonates with the soul of his ancestors.
#
#
# The warrior, known as Akar, was born in the vibrant city of Taxila, the heart of the Gandhara civilization, around 170 CE. Son of a revered sculptor, Akar grew up among the masterpieces of art that adorned the stupas and monastic complexes dotting the landscape. His father imbued in him a passion for the arts, but Akar's heart leaned towards the call of valor and the dharma he had learned from the teachings of Buddhism.
#
# As a youth, Akar was mesmerized by tales of the Buddha’s past lives, recounting not just supernatural ascensions but also earthly battles against ignorance and evil. His training began early; he was tutored in martial skills by the seasoned warriors who protected the sacred relics of the stupas. It wasn’t long before he became a formidable figure, his physique sculpted from rigorous training, reminiscent of the very statues he admired. Muscles rippling, he wore armor that blended local craftsmanship with Hellenistic designs, embodying the rich cultural exchanges that marked his nation.
#
# Akar fought bravely in various skirmishes against marauding tribes threatening the sanctity of their land. Dressed in ornate armor, decorated with motifs symbolizing protection and strength, he wielded a beautifully curved sword—a family heirloom—as well as a shield that bore intricate carvings of celestial beings. His expression was one of determination and bravery, channeling the energy of the Bodhisattvas he aspired to emulate.
#
# In the quiet moments after battle, Akar often found solace by the stupas, engaging in meditation to reflect on the balance between the warrior’s path and the teachings of compassion. He understood that the true essence of being a protector was not solely in physical strength but in upholding the values of peace and enlightenment. Akar thus became a living embodiment of Gandharan artistry and spirituality, a warrior not just in combat, but in the unwavering pursuit of wisdom and truth that resonates with the soul of his ancestors.
